pdf
https://attra.ncat.org/wp-content/uploads/2019/05/IP543.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/pawpaw.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/cashcropping.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/manure.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/ethanol.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/pasturerule.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/brokers_tipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/internettipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/bison.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/carne.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/peach_diseases_diagnostic_key.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/plum.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/egghandling.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/pecan.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/cotton.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/beefchec.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/localfoods1.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/foodsafety.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/ozarksfruit.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/meatchicken.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/inspeccion.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/squash_pest.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/distributorstipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/croppingsystems.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/cropsfarmplan.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/valueovr.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/mgmt_internal_external_parasites.pdf
https://attra.ncat.org/wp-content/uploads/2019/10/SP590-Solar.png
https://attra.ncat.org/wp-content/uploads/2019/05/grapes.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/csa.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/garlic.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/rumiantes.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/spaninternet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/spandistribuidores.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/copper_wire.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/cover_crops_in_organic_systems.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/nutrient_mgmt.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/hooped.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/scalingup.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/farmscaping.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/workingwithyourmeatprocessor.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/pastures_organic.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/solarwatering.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/manejo_integrado.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/sweetpotato.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/energia_renovable.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/farmcity.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/ginsgold.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/nongmodairytransition.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/certificacion_organicas.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/storedgrain.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/ovinos_ilustrada.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/farmbiz_structures_tipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/plums.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/crop_rotation_organic_systems.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/apple.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/WFRP-tipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/postharvest.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/paddock.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/irrigpasturestipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/predator.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/restauranttipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/quickstart.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/spanagroturismo.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/companion.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/multispeciesgrazing.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/gmocrops.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/dungbeetle.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/greenhouseipm.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/smallgrain.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/manures.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/hog.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/sweetcorn.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/spangrocerytipsheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/soil_assessment_esp.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/impuestosdeingresos.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/livestock_living_conditions_esp.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/spanplantasdeembalaje.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/organic_orchard_management.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/CAlabor_law_case_studies.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/documentationforms_intro.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/lettuce.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/all_marketing_tip_sheets.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/stink-bugs-tip-sheet.pdf
https://attra.ncat.org/wp-content/uploads/2019/05/wind.pdf'''

# %%
import os

for url in urls.split():
    filename = url.split('/')[-1]
    os.system(f'curl -o {filename} {url}')

# %%
from pdfminer.high_level import extract_text

# %%
wind = extract_text('wind.pdf')

# %%
print(wind)
# Out:
# Wind-Powered Electric Systems for
# Homes, Farms, and Ranches: Resources
#
# A Publication of ATTRA - National Sustainable Agriculture Information Service  •  1-800-346-9140  •  www.attra.ncat.org
#
# This publication provides a description of information available on wind resources, wind energy ﬁnanc-
# ing, wind power on the Web, and other wind energy basics to help you decide whether and how to
# start turning wind power into electricity. It may be easier than you think to get started on your own
# wind energy project.
#
#
#
# ATTRA
#
# By Al Kurki and
# Amanda Hill
# NCAT Agriculture
# Specialists
# © NCAT 2005
#
# Contents
#
# More In-depth
# Resources .......................... 2
#
# Good Places on the Web
# to Learn More About
# Wind Power  ..................... 3
#
# Siting Large Scale Wind
# Power on Your Land ...... 3
#
# Small Wind Electric Systems: A U.S.
# Consumers’ Guide
# A 27-page booklet published in March
# 2005 by the National Renewable Energy
# Laboratory.
# ...
